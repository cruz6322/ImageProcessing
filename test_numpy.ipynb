# %%
import numpy as np

# %%
list1 = [1,2,3]
a = np.ones((1,3), np.uint8)
b = np.array(list + a

print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 list1 = [1,2,3]
#       2 a = np.ones((1,3), np.uint8)
# ----> 3 b = list + a
#       5 print(a)
#       6 print(b)
#
# TypeError: unsupported operand type(s) for +: 'type' and 'int'

# %%
s = int(input("숫자 입력 : "))

if s == 3:
    print("correct!")
    
else:
    print("error")
# Out:
# 숫자 입력 :  ４
# error

# %%
ｉｍｐｏｒｔ ｎｕｍｐｙ
# Out:
#   Cell In[4], line 1
#     ｉｍｐｏｒｔ ｎｕｍｐｙ
#            ^
# SyntaxError: invalid syntax
